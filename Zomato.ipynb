# %%
import pyforest as py

# %%
df = pd.read_csv("zomato.csv",encoding = "latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df["Cuisines"]
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
df[df["Cuisines"].isnull()]    #name of dataframe[condition]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df1 = pd.read_excel("Country-Code.xlsx")

# %%
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
[feature for feature in df.columns if df[feature].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.columns.isnull().sum()>0
# Out:
# np.False_

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Cuisines'], dtype='object')

# %%
df2 = pd.merge(df,df1,on='Country Code',how = "left")

# %%
df2 = pd.merge(df,df1,on = 'Country Code',how = 'left')

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2["Country"].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
df2.Country.value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
df2["Country"].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
df2["Country"].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
plt.pie(df2.Country.value_counts()[:3],labels = df2['Country'].value_counts().index[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x27cf28e5d90>,
# ...
#  [Text(-1.082974277862112, 0.1927867046480056, 'India'),
#   Text(1.0772816964394372, -0.22240536530526556, 'United States'),
#   Text(1.0995865232164619, -0.030157552300104404, 'United Kingdom')])

# %%
df2["Country"].value_counts().index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'South Africa',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Singapore', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2.to_csv(r'C:\Users\aditya chourasia\OneDrive\Desktop\DS\EDA\zomatooperation\final_df.csv')

# %% [markdown]
# Easy Level
#
# How many unique cities are represented in the dataset?   done
#
# What are the top 5 countries with the most restaurants listed?   done
#
# What are the most common cuisines?         done
#
# How many restaurants offer online delivery?     done
#
# What are the different rating colors and how many restaurants fall under each?

# %%
city = df["City"].value_counts().index

# %%
type(city)
# Out:
# pandas.core.indexes.base.Index

# %%
a = 0
for i in city:
    if(i=='Makati City'):
        print("True")
        print(a)
    a = a+1
# Out:
# True
# 89

# %%
df2['Country'].value_counts()[:5]
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# Name: count, dtype: int64

# %%
df2['Cuisines'].value_counts()[:5]
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
df[df["Has Online delivery"] == "No"]['Restaurant Name']
# Out:
# 0               Le Petit Souffle
# 1               Izakaya Kikufuji
# 2         Heat - Edsa Shangri-La
# 3                           Ooma
# 4                    Sambo Kojin
#                   ...
# 9546                NamlÛ± Gurme
# 9547               Ceviz AÛôacÛ±
# 9548                       Huqqa
# 9549                Aôôk Kahve
# 9550    Walter's Coffee Roastery
# Name: Restaurant Name, Length: 7100, dtype: object

# %%
df[df["Has Online delivery"] == "Yes"]["Restaurant Name"]
# Out:
# 565               Famous Dave's Barbecue
# 566                       Pizza Di Rocco
# 571     Cho Gao - Crowne Plaza Abu Dhabi
# 572                               Gazebo
# 573      Sangeetha Vegetarian Restaurant
#                       ...
# 9166                             Chili's
# 9168                          Blue Water
# 9170                     Tales & Spirits
# 9171             18 Degrees Resto Lounge
# 9194                      Saffron Mantra
# Name: Restaurant Name, Length: 2451, dtype: object

# %%
df[df["Has Online delivery"] == "No"]
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
df2.groupby(['Aggregate rating','Rating color','Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
data = df2['Rating color'].value_counts().reset_index()

# %%
data
# Out:
#   Rating color  count
# 0       Orange   3737
# 1        White   2148
# 2       Yellow   2100
# 3        Green   1079
# 4   Dark Green    301
# 5          Red    186

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns = ['Count', 'Resturant_count']

# %%
data.columns = ['Rating colour','Resturant count']

data
# Out:
#   Rating colour  Resturant count
# 0        Orange             3737
# 1         White             2148
# 2        Yellow             2100
# 3         Green             1079
# 4    Dark Green              301
# 5           Red              186

# %%
data
# Out:
#   Rating colour  Resturant count
# 0        Orange             3737
# 1         White             2148
# 2        Yellow             2100
# 3         Green             1079
# 4    Dark Green              301
# 5           Red              186

# %% [markdown]
# What is the average rating of restaurants by city?  done
#
# How does the average cost for two vary across different countries?   done
#
# What are the top-rated cuisines globally?          done
#
# Which restaurants have the highest number of votes        done
#
# Compare the availability of table booking vs online delivery across countries.        done

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df["City"].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
df[(df["City"]=="New Delhi") & (df["Aggregate rating"]>0)]['City'].value_counts().sum()
# Out:
# np.int64(4048)

# %%
df[df['City'] == "New Delhi"]['Aggregate rating'].sum()
# Out:
# np.float64(13347.8)

# %%
df[(df['City']=='New Delhi') & (df['Aggregate rating']>0)]['Aggregate rating']
# Out:
# 2561    3.2
# 2562    3.4
# 2563    2.6
# 2564    3.4
# 2565    3.1
#        ...
# 8005    3.2
# 8006    2.7
# 8007    3.0
# 8008    3.9
# 8009    3.7
# Name: Aggregate rating, Length: 4048, dtype: float64

# %%
df[(df['City']=='New Delhi') & (df['Aggregate rating']>0)]['Aggregate rating'].sum()/df[(df["City"]=="New Delhi") & (df["Aggregate rating"]>0)]['City'].value_counts().sum()
# Out:
# np.float64(3.2973814229249014)

# %%
df[(df["City"]=="New Delhi") & (df["Aggregate rating"]>0)]['City'].value_counts().sum()
# Out:
# np.int64(4048)

# %%
low  = 0
for i in df2['Aggregate rating']:
    if(low<i):
        low = i
print(low)
# Out:
# 4.9

# %%
df[df['Aggregate rating']==4.9][['Cuisines','City']].value_counts().sum()
# Out:
# np.int64(61)

# %%
low = 0
for i in df2['Votes']:
    if(low<i):
        low = i
print(low)
# Out:
# 10934

# %%
df[df['Votes']==low]['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Toit    1
# Name: count, dtype: int64

# %%
df2[df2['Has Table booking']=='Yes']['Country'].value_counts()
# Out:
# Country
# India             1111
# UAE                 18
# Phillipines         14
# United Kingdom      12
# South Africa         2
# Qatar                1
# Name: count, dtype: int64

# %% [markdown]
# Is there a correlation between price range and aggregate rating?
#
# Do restaurants that offer table booking tend to have higher ratings?
#
# Using clustering (e.g., K-means), can you group restaurants based on rating, price range, and delivery options?
#
# Can you predict the rating text using features like price range, votes, table booking, and delivery availability? (classification problem)
#
# How does the average cost for two compare across different cuisine types and countries combined (e.g., Indian food in India vs in UAE)?

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2[(df2['Has Table booking'] == 'Yes') & (df2['Aggregate rating'] > 0)]['Aggregate rating'].sum()
# Out:
# np.float64(3985.8)

# %%
df2[(df2['Aggregate rating']>0) & (df2['Has Table booking'] == 'Yes')].value_counts().sum()
# Out:
# np.int64(1111)

# %%
df2[(df2['Has Table booking'] == 'Yes') & (df2['Aggregate rating'] > 0)]['Aggregate rating'].sum()/df2[(df2['Aggregate rating']>0) & (df2['Has Table booking'] == 'Yes')].value_counts().sum()
# Out:
# np.float64(3.5875787578757876)

# %%
df2[(df2['Has Table booking'] == 'No') & (df2['Aggregate rating'] > 0)]['Aggregate rating'].sum()
# Out:
# np.float64(21480.7)

# %%
df2[(df2['Has Table booking'] == 'No') & (df2['Aggregate rating'] > 0)]['Aggregate rating'].sum()/df2[(df2['Aggregate rating']>0) & (df2['Has Table booking'] == 'No')].value_counts().sum()
# Out:
# np.float64(3.4188604169982493)

# %%
df2[(df2['Aggregate rating']>0) & (df2['Has Table booking'] == 'No')].value_counts().sum()
# Out:
# np.int64(6283)

# %%
lable = ["Has Table Booking","Has no Table Booking"]
size = [3.58,3.41]
plt.bar(lable,size,color = ['blue','red'])
plt.xlabel = 'category'
plt.ylable = 'Average rating'

# %%
df[df['Cuisines'] == '%Indian%'].value_counts().sum()
# Out:
# np.int64(0)

# %%
df[df['Cuisines'].str.contains('Indian', case=False, na=False)].value_counts().sum()
# Out:
# np.int64(4259)

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False)].shape[0]
# Out:
# 4259

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='India')].shape[0]
# Out:
# 4191

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='UAE')].shape[0]
# Out:
# 26

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='India')]['Average Cost for two'].sum()
# Out:
# np.int64(2840550)

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='UAE')]['Average Cost for two'].sum()
# Out:
# np.int64(4190)

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='India')]['Average Cost for two'].sum()/df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='India')].shape[0]
# Out:
# np.float64(677.7738010021475)

# %%
df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='UAE')]['Average Cost for two'].sum()/df[df['Cuisines'].str.contains('Indian',case=False,na = False) & (df2['Country']=='UAE')].shape[0]
# Out:
# np.float64(161.15384615384616)

# %%
size = [677,161]
label = ["India","UAE"]
plt.bar(label,size)
plt.xlabel('Country')
plt.ylabel("Average cost of Indian Cuisine")
plt.title("Data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 4
#       2 label = ["India","UAE"]
#       3 plt.bar(label,size)
# ----> 4 plt.xlabel('Country')
#       5 plt.ylabel("Average cost of Indian Cuisine")
#       6 plt.title("Data")
#
# TypeError: 'str' object is not callable
